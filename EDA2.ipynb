# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharadwaj0906/Airline-Passenger-Satisfaction-Project/blob/main/EDA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Airline Passenger Satisfaction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1) Why this  Project

# %% [markdown]
# •	This EDA project is to analyze the dataset. This project is to analyze the satisfaction of passenger. The purpose of choosing this data set is I want to analyze in airline industry how customers are satisfied with the service of the airline company. The data sets contains ratings of all services provided by the airline so by analyzing the dataset we can come to conclusion why the customer is satisfied or not satisfied and where airline should increase their services I can suggest it. So I have choose this data set to analyze this all conclusions.

# %% [markdown]
# ### 2) Which Domain it belongs to?

# %% [markdown]
# •	The given Dataset belongs to Airline Industry which comes under the Business Domain.

# %% [markdown]
# ### 3) Information About Data

# %% [markdown]
# •	The Data is about did passengers are satisfied to the services of airline. The data contains 103904 rows and 25 columns. It contains data of 103904 customers. It contains information about id of the passenger, Gender of the passenger, Customer Type, Age of the Passenger, Type of Travel, What type of class the passengers are chosen, Flight Distance and it has ratings for In-flight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, In-flight entertainment, On-board service, Leg room service, Baggage handling, Check in service, In-flight service, Cleanliness and also Datasets says about Departure and Arrival delay and finally Dataset has the column satisfaction of customer.

# %% [markdown]
# ### 4)What is my approach??

# %% [markdown]
# •	My approach is Quite Simple I will first do the Quantity analysis and find the relationship between the columns and I will check if there is any null, duplicate, irrelevant values and i will delete these values. I will choose one column and if the column is numerical I will check if the column has outliers and i will replace outliers and I will analyze the columns by using the numerical graphs like box plot, histplot etc. I will analyze the categorical columns with barplots,countplots,piecharts. Finally after the analyzing the columns i will come to one conclusion that how many passengers are satisfied and not satisfied and by analyzing the ratings of passengers I will conclude that in which areas Airline industry should increase their facilities or their service so that their business can increase.

# %% [markdown]
# 1) Perform data preparation and cleaning using pandas and numpy<br>
# 2) perform exploratory analysis and visualization using matplotlib and seaborn<br>
# 3) Ask and answer questions about the data in jupyter notebok<br>
# 4) summarize my infrences and write a conclusion<br>

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# ### Data Sourcing
# 1) reading data by using pandas

# %%
df=pd.read_csv("/content/drive/MyDrive/EDA project/Project1.csv")

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %% [markdown]
# ### Quantity Analysis
#
# In quantity analysis we will find what are the columns and what are their data types and we will find descriptive statics of the data

# %%
df.shape
# Out:
# (103904, 25)

# %% [markdown]
# The data set contais 103904 rows and 25 columns

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# It gives us the  first 5 rows of the data set

# %%
df.tail()
# Out:
#         Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 103899      103899  94171  Female  disloyal Customer   23  Business travel
# 103900      103900  73097    Male     Loyal Customer   49  Business travel
# 103901      103901  68825    Male  disloyal Customer   30  Business travel
# 103902      103902  54173  Female  disloyal Customer   22  Business travel
# 103903      103903  62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 103899                                  1  ...                       2
# ...

# %% [markdown]
# It gives us the last 5 rows of the data set

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# Here we can see what are the different  columns present in the dataset.The data set contains columns-
# 'Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel','Class', 'Flight Distance', 'Inflight wifi service','Departure/Arrival time convenient', 'Ease of Online booking','Gate location', 'Food and drink', 'Online boarding', 'Seat comfort','Inflight entertainment', 'On-board service', 'Leg room service','Baggage handling', 'Checkin service', 'Inflight service','Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in  Minutes','satisfaction'.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %% [markdown]
# Here we are finding what is the datatype of the each column which belong to this data set.Here all columns has the correct datatype.But "Arrival Delay in Minutes"  column has the datatype float it will be more efficient if we change the datatype into int because the column says us about what is the delay in arrival in minutes so if the minutes can be int.So the datatype will be changed after the checking null values and if it has null values the null values will be replaced and removed and we will change the datatype.

# %% [markdown]
# we cand find the descriptive stastics of the numerical columns  of the data set

# %% [markdown]
# ### Perform data  cleaning using pandas and numpy

# %% [markdown]
#  Fix any missing and incorrect values
#
#  •	Let us prepare and clean our dataset for further data analysis.
# So  firstly let us check with there are any unwanted columns in our dataset .So there is a column “Unnamed : 0” which is just giving the row numbers so there is no need of this column for analysis.

# %%
sns.histplot(df["Unnamed: 0"])

# %% [markdown]
# As we can see the each variable in the column “Unnamed: 0” has the same count
# And it is showing row numbers so let us drop this column because it is not necessary for analysis. Now there is a column called “ID” it has all unique Ids of a customer so it is also not necessary for  any analysis so let us drop the column “ID”.

# %%
sns.distplot(df.id.sort_values())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# So in our data there is two columns which are not necessary for analysis so these two columns has been deleted.

# %%
df1 = df.drop(['Unnamed: 0',"id"], axis=1)
df1.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %% [markdown]
# In the data set the columns Unnamed:0 and Id are not useful for the analysis so i just dropped these two columns.Because the Unnamed:0 just gives us the row numbers and id gives us the unique id values.From the id values we cannot analyse anything so i just dropped these two columns.

# %%
duplicate_values=df1.duplicated().sum()
duplicate_values
# Out:
# 0

# %% [markdown]
# In the dataset there is no duplicate values.Now we will check with the null values.

# %%
df1.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
null=df1.isnull().sum()

# %%
plt.figure(figsize=(12,6))
null.plot(kind="barh")

# %% [markdown]
# Here we can see only one column  “Arrival Delay in Minutes” column has the null values. The column “Arrival Delay in Minutes” has the null values it has 310 null values so we have to remove or replace our null values. We will  replace our null values so to replace our null values we will check it outliers let us come to that it should be replaced with mean or median or mode.

# %%
sns.boxplot(df1["Arrival Delay in Minutes"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Arrival_Delay_mean=df1["Arrival Delay in Minutes"].mean()

# %%
print(Arrival_Delay_mean)
# Out:
# 15.178678301832152

# %% [markdown]
# We will replace our null values with mean of the values of this column. The mean of the values of this column is “15.17” so we will just replace all the null values with this value. As it is arrival delay of flight we are just calculating average delay in arrival and replacing in the place off null values. Now all null values are replaced and there is no null values in our dataset.

# %%
df1["Arrival Delay in Minutes"].fillna(Arrival_Delay_mean,inplace=True)

# %%
df1.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# Now let us check what is the data type of each column present in our dataset and  if any changes required to change data type we have to change the data type.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %%
df1["Arrival Delay in Minutes"]=df1["Arrival Delay in Minutes"].astype(np.int64)

# %%
df1.head(2)
# Out:
#   Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0   Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1   Male  disloyal Customer   25  Business travel  Business              235
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %% [markdown]
# So we can see data types of all columns present in dataset here there is nothing much to change the data types but there is a column “Arrival Delay in Minutes”  if we change the data type from float to integer it will be more efficient for analysis. Let us change the data type from float to int.
#
# So  we have cleaned and prepared our data set for further data analysis .we have checked if there is any unnecessary columns and we have dropped it and we checked if there is any duplicated values and null values and we have replaced and removed it. So our data is ready for further data analysis.

# %% [markdown]
# ## perform exploratory analysis and visualization using matplotlib and seaborn
# ### Univariate Analysis and Bivariate Analysis:
#
#
# •	Univariate analysis is perhaps the simplest form of statistical analysis. Like other form of statistics, it can be inferential or descriptive. The key fact is only one variable is involved.
#
# •	Bivariate analysis  is one of the simplest forms of quantitative (statistical) analysis. It involves the analysis of two variables (often denoted as X, Y), for the purpose of determining the empirical relationship between them.
# Bivariate analysis can be helpful in testing simple hypotheses of association. Bivariate analysis can help determine to what extent it becomes easier to know and predict a value for one variable (possibly a dependent variable) if we know the value of the other variable (possibly the independent variable) (see also correlation and simple linear regression).
# Bivariate analysis can be contrasted with univariate analysis in which only one variable is analyzed. Like univariate analysis, bivariate analysis can be descriptive or inferential. It is the analysis of the relationship between the two variables. Bivariate analysis is a simple (two variable) special case of multivariate analysis (where multiple relations between multiple variables are examined simultaneously).
#
# Let us first analyze all the categorical variables:
#
# Categorical univariate data consists of non-numerical columns that may be placed in categories. It includes labels or names used identify an attribute of each element. Categorical univariate data usually use either nominal or ordinal scale of measurement. Categorical may be in order or unordered data.
#
#
#
# Gender:
#
# •	Here in this column we have gender who traveled in airline. Let us analyze this column.

# %%
sns.set_style("darkgrid")
sns.countplot(df1.Gender)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In this we can clearly analyze that there are more female customers for airline business than male. The difference is not too much there is only small difference between female and male who are travelling in airline. We can see total number of female who are travelling in airline is “52,727” and male is “51,177”. So we can say female travelling  in airline is slightly higher than male travelling in airline.

# %% [markdown]
# Now let us plot the graph between Gender and satisfaction.

# %%
df1_Gender=pd.crosstab(index=df["Gender"],columns=df["satisfaction"],normalize="index")

# %%
plt.figure(figsize=(12,10))
df1_Gender.plot(kind="bar")

# %% [markdown]
# As we can see here both female and male are mostly equal in terms of satisfied or neutrally or dissatisfied. We can analyze both male and female are more neutral or dissatisfied. So we should analyze why they are neutrally satisfied or dissatisfied.

# %% [markdown]
# Customer Type:
#
# •	This column tells us about the customer type. In this column it has two customer types loyal and disloyal. Loyal customer means who are making repeat travel in airline and disloyal means who are not repeatedly travelling in airline.

# %%
sns.countplot(df["Customer Type"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In this graph we can analyze that there are more loyal customers than disloyal customers. As we can see there are “84923” loyal customers and “18981” disloyal customers. So we can say that there more loyal customers means who are repeatedly travelling in airline and who are booking tickets for airline is more.

# %% [markdown]
# Type Of Travel:
#
# •	This column tells us about what is type of travel the customer has been traveling for. Basically there are two types of travel they are and Business travel and personal travel so let us analyze this column  and find out what is the most commonly type the customer is travelling for.

# %%
sns.countplot(df1["Type of Travel"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In this graph we can clearly analyze that there are more people traveling for business travel than personal travel there are more tickets booking for business travel than personal travel. People traveling for business travel is “71655” and for personal travel is “32249” .So we can clearly say the more people more travelling in airline for Business purpose.
#
# Now let us plot a graph between customer type and satisfaction.
#
# We should analyze which type of travel is highly dissatisfied or highly satisfied.

# %%
df1_typeoftravel=pd.crosstab(index=df1["Type of Travel"],columns=df1["satisfaction"],normalize="index")

# %%
df1_typeoftravel.plot(kind="bar",figsize=(6,6),stacked=True)

# %% [markdown]
# As Age highlighted, airline may have issues providing support to those with particular needs. This suspicion is enforced when the purpose of travel is examined. For personal travelers, reported a extremely high, 90%, rate of dissatisfaction.
# This is not to discount the need for modernization. Firstly, dissatisfaction amongst personal travelers did not appear to alter with age. In addition, business travelers under 40s business also reported issues with the service

# %% [markdown]
# Class:
#
# •	In this column we can analyze that what is class of the seat the customer has been booked. There are three types of class they are Eco, Ecoplus and Business Class. So these are three types of class of seat the customers can be book. Where Eco is cheapest price and Business Class has highest price of ticket has the price differs the facilities also differs in the class of seat. The Business Class has more facilities than ecoplus and eco. The Ecoplus has more facilities than Eco.

# %%
plt.figure(figsize=(12,9))
df2=df1["Class"].value_counts()
plt.pie(df2,autopct="%.0f%%",labels=df2.index);

# %%
sns.countplot(df1["Class"],hue=df1["satisfaction"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The dissatisfaction between different classes of passengers suggests that there are some particular issues affecting the Economic tickets, as the rate of dissatisfaction amongst this group is over 80%. Eco Plus also has issues to a limited extent. Business class appears to be the best performing with the dissatisfaction rate as low as 31%.
# Whilst this suggest a need for the airline to investigate its Economy ticket offering, there is a need to confirm with the airline on their strategic decisions. If the airline wishes to be one which predominantly cater for business travelers, this aspect may have been accounted for and accepted. Given that there are more business class travellers, the airline may be justified in their decision but it will be dependent on the profitability of this strategy

# %% [markdown]
# As we can see here clearly the more people choose business class or Eco class. There is only slight difference between Eco and Business. The Eco is “45%”, EcoPlus is “7%”, Business is “48 %”. So we can analyze that customers are mostly interested to book in higher class that is Business class or lower class that is Eco which has cheapest price compare to other two Classes

# %% [markdown]
# Satisfaction:
#
#
# •	This column tells us that customers are satisfied or dissatisfied for facilities provided by airline and various reasons like flight distance, arrival and departure delay of flight.

# %%
plt.figure(figsize=(12,9))
df1_satisfaction=df1["satisfaction"].value_counts()
plt.pie(df1_satisfaction,autopct="%.0f%%",labels=df1_satisfaction.index,colors=["Red","LightGreen"]);

# %% [markdown]
# So we can clearly see surprisingly the neutral or dissatisfied is more than satisfied.
# The Satisfied is “43%” and neutral or dissatisfied is “57%”.So now we have analyze the data set and we should come to a conclusion that why satisfied is less than neutral or dissatisfied and on what basis customer gave that they are satisfied or neutral or dissatisfied. So we can say that airline should increase more facilities to more satisfy the customer.
#
# We have analyzed all categorical columns. Now let us analyze the numerical columns.

# %% [markdown]
# Age:
#
# •	In this column we can see different type of ages who are travelling in airline. So let us see between which age group is travelling in more airline.

# %%
plt.figure(figsize=(14,10))
sns.countplot(df.Age)
plt.xticks(rotation=90);
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# We can see here clearly that age group between  20 to 60 are clearly high in high travelling in airline. The age group “39” is the highest age group where most number of people travelling in this age group. Between  20 to 60 there more than 1500 customers in each age group.
#
# Now lets us check which age group is most satisfied or neutral or dissatisfied. From this we will check what may be the reasons for satisfied or neutral or dissatisfied.

# %%
sns.displot(x = "Age", data = df, hue ="satisfaction",height=8,palette=["C0","C1"]  )

# %% [markdown]
# As we can see in this plot between the age group 40 to 60 are more satisfied other then this age group all other age group are mostly dissatisfied or neutrally satisfied.
#
# This suggests several issues including:
# •	Airline not servicing parties with particular needs such as young families and those with medical issues,
# •	Aspects of the services require modernizing

# %% [markdown]
# Flight Distance:
#
# Airlines typically alter or even specialize in specific flight distances. This is not only because the provided service such as meals can differ but also because the aircrafts for such journeys can also vary.

# %%
plt.figure(figsize=(12,9))
sns.distplot(df["Flight Distance"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# As we can see the flight distance is more is between 0 to 1000.We can see more density for distance for 0 to 1000.

# %%
plt.figure(figsize=(12,9))
sns.boxplot(df["Flight Distance"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# We can analyze from this box plot that there some outliers in these column but we cannot drop and replace these outliers because there can be Flight Distance of 3800 and till 5000.But we can come to conclusion these are the longest distance flights and these flights can be mostly international Flights.
#
# Now let us see with the satisfaction. Let us find if the Distance is more the customers are satisfied or if the Distance is less the customers are satisfied.

# %%
plt.figure(figsize=(12,9))
sns.histplot(x="Flight Distance",data=df1,hue="satisfaction",palette=["Green","Red"])

# %% [markdown]
# For this airline, the focus appears to be on long haul, above 1500km, flight. These flights are viewed positively by the passengers with 66% satisfaction. However, short haul flights, under 1500km, appear to be a weakness with rate of dissatisfaction is approx. 66.5%.
# Confirmation with the airline is required but this too may be a reflection of the business strategy by the airline. If the airline wishes to compete with short haul airlines such as Ryanair, major changes to the operation may be needed. If, on the other hand, they wish to focus on long haul, they may need to look at the operations of BA, Emirates and other carriers.

# %% [markdown]
# Flight delays:
#
# Delays are a major issue for any airline. It can affect not only the passenger's satisfaction but the scale of the delays could lead to airlines needing to offer refunds and hotel accommodation, depending on the governing laws. In addition, it may also cause scheduling issues as staff and planes are located in incorrect locations. Subsequently flight delays should be examined on its own to understand possible causes and whether similar issues can be mitigated. If the issue was related to parking space and a specific airport, the airline may wish to engage in discussions with said airport.
#
# Let us see the plot of Departure Delay in minutes.

# %%
plt.figure(figsize=(12,9))
sns.distplot(df1["Departure Delay in Minutes"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# As we can see it is a left skewed normal distribution. Now let us check with Arrival Delay in minutes.

# %%
plt.figure(figsize=(12,9))
sns.distplot(df1["Arrival Delay in Minutes"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# So Arrival Delay in Minutes is also a left Skewed normal distribution.
# We can see both delays are same so we should see is there any relation between them.
#
# Now let us check the customers are satisfied or dissatisfied with relation of delays.
#
# First let us check with the Departure Delay in Minutes and satisfaction.

# %%
plt.figure(figsize=(12,9))
sns.violinplot(x = 'Departure Delay in Minutes', data = df1,y="satisfaction", palette ="Paired")

# %% [markdown]
# Let us check with Arrival Delay in Minutes

# %%
plt.figure(figsize=(12,9))
sns.violinplot(x = 'Arrival Delay in Minutes', data = df1,y="satisfaction", palette ="Paired")

# %% [markdown]
# Now let us check with Total Delays.

# %%
df1["Total_delay_minutes"] = df1['Arrival Delay in Minutes']+ df1["Departure Delay in Minutes"]
df1["Total_delay_hours"] = round(df1["Total_delay_minutes"]/60,1)

# %%
df1["Total_delay_hours"]
# Out:
# 0         0.7
# 1         0.1
# 2         0.0
# 3         0.3
# 4         0.0
#          ...
# 103899    0.0
# 103900    0.0
# 103901    0.4
# 103902    0.0
# 103903    0.0
# Name: Total_delay_hours, Length: 103904, dtype: float64

# %%
plt.figure(figsize=(12,9))
sns.violinplot(x = 'Total_delay_hours', data = df1,y="satisfaction", palette ="Paired")

# %% [markdown]
# As one may expect, examine total delays, arrival and departure delays, it is clear that longer the delay the customers were more likely to be unsatisfied with the services. We can analyze that customers are not satisfied with delays.

# %% [markdown]
# Services:
#
# The second aspect of the survey is the passenger's rating on the services they received before and during their travel from the airline. Each of these are rated between 1 and 5 with 0 used to indicate a null value or not applicable. The accumulated scores indicate that there is a relationship between the services they received and their overall evaluation of the airline. Those who rated the service poorly were more inclined to rate the overall service as unsatisfactory.
# The following section will evaluate these responses and suggest the importance of improving a specific aspect of the service alongside how it may affect passenger feedback. Specific focus will be placed upon the nature of travel and, where required, the ticket class. This is to examine whether the trends identified alters when this variable is added. The reasons for focusing on these variables are due to the apparent strategic focus of the airline on one group of travelers and therefore they may wish to weight the suggestions differently based on this factor.
#
# First I have calculated the average of all ratings so let us analyze what  is the number of highest rating and number of lowest ratings.

# %%
Total_rating=df1.iloc[:,6:20].sum(axis=1)

# %%
Total_rating
# Out:
# 0         54
# 1         32
# 2         52
# 3         42
# 4         49
#           ..
# 103899    31
# 103900    61
# 103901    43
# 103902    32
# 103903    28
# Length: 103904, dtype: int64

# %%
avg_rating=Total_rating//14
avg_rating
# Out:
# 0         3
# 1         2
# 2         3
# 3         3
# 4         3
#          ..
# 103899    2
# 103900    4
# 103901    3
# 103902    2
# 103903    2
# Length: 103904, dtype: int64

# %%
plt.figure(figsize=(12,9))
sns.countplot(avg_rating)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# We can analyze from here that most customers gave 3 rating more and 5 rating is less given by the customers followed by 1,4,2 ratings.
# Now let us see with satisfaction what is the highest and lowest number of ratings given by customers.

# %%
df2=pd.crosstab(index=df["satisfaction"],columns=avg_rating,normalize="index")

# %%
df2
# Out:
# col_0                           1         2         3         4         5
# satisfaction
# neutral or dissatisfied  0.038825  0.467909  0.458602  0.034664  0.000000
# satisfied                0.007929  0.120866  0.577568  0.293481  0.000155

# %%
df2.plot(kind="bar",stacked=True,figsize=(10,9))

# %% [markdown]
# In this plot we can clearly see the average ratings difference between neutral or dissatisfied and satisfied. As we can see in satisfied the average rating of 3 and 4 is more compared to neutral and dissatisfied and for neutral and dissatisfied average rating of 2 and 3 is more compared to satisfy. So we can clearly analyze that the customers who are neutral or dissatisfied are given low ratings compared to satisfy. So we have to find in service aspect customers gave low ratings.

# %% [markdown]
# Ease of Online booking:
#
# Ease of booking appears to indicate that amongst those who rated the service as 4-5, their overall dissatisfaction was as low was 26%. This suggests that investment in this remit would encourage a improved perception of the airline. Encouragingly, this is an area of service which appears to be valued about both business and personal travelers. As such, regardless of the airline's business strategy, investment here would be beneficial.

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Ease of Online booking"],hue=df1["satisfaction"],palette=("Pink","Green"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# We can analyze from this plot that for the customers how are satisfied with the Ease of online bookings gave highest ratings as 4 and 5 and who are neutral or dissatisfied gave ratings 2 and 3 more. The highest number of ratings is 2 and 3 that is also given by neutral or dissatisfied. So I think airlines should concentrate on Ease of online Booking to satisfy the customers.
# Furthermore, online bookings may be the first point of contact for a perspective customer. As such, an improvement here posses a possibility of increased cliental.

# %% [markdown]
# Online Boarding:
#
# Let us find the ratings of Online Boarding.

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Online boarding"],hue=df1["satisfaction"],palette=("Red","Yellow"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The review of the online booking scores further encourages investments in the airline's online platform. Once again as the scores for online bookings increase, the overall dissatisfaction appears to decrease. In addition, compared to ease of online booking, the scale of decrease in dissatisfaction and increase in scores, highlights that this is an area highly valued by passengers.

# %% [markdown]
# Check-in service:
#
# Let us analyze Check in service.

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Checkin service"],hue=df1["satisfaction"],palette=("Black","Brown"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In contrast to online services, the check-in service appears to have a limited impact on overall satisfaction. Whilst previously when the scores were 4 or above the majority of the passengers rated the overall service satisfactory, here even at a score of 4, over 54% of the passengers indicated dissatisfaction.
# This is not to say that all groups of passengers discounted the value of check-in services. Business travelers appear to value this service. Therefore, the airline may have reasons to invest in this area depending on their business strategy. However, as with online services, they may reap more benefits from improving other aspects of the business before tackling check-in services. Please refer to the suggested order of improvements.

# %% [markdown]
# Baggage handling:
#
# Let us find the ratings of Baggage handling.

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Baggage handling"],hue=df1["satisfaction"],palette=("Grey","orange"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Analysis of Baggage handling appears that similar to other variables. As the score increase, the dissatisfaction decreases. However, the breakdown by travel type indicate that this is a feature is not particularly valued deeply by personal travelers as the level of dissatisfaction remains relatively stable regardless of the score.
# Therefore the airline may see greater benefits from focusing first on other aspects of passenger experience. That said, the airline should pay attention to any issues at airports such as the following: A worker at one of Europe's busiest airports says a lack of confidence in baggage handling is leading to flight delays
# Such reports may cause other issues with the passenger experience leading to a negative perception of the airline..

# %% [markdown]
# Departure/Arrival time convenient:

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Departure/Arrival time convenient"],hue=df1["satisfaction"],palette=("LightGreen","Purple"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The departure and arrival time appears to have minimum impact on the overall satisfaction level. Regardless of the score given to the time, the levels of dissatisfaction remain high and in fact between 3 and 4, overall dissatisfaction increases by 5 percentage point.
# Examining the variable with regards to the passenger's travel reason, business travelers appear to value the convenience as increase in scores can lead to a decrease in dissatisfaction by approx. 18 percentage points. However, for personal travelers, there is no distinct pattern in the relationship between overall dissatisfaction and convenient time. As such, valuing this aspect and investing in its improvement will be dependent upon airline's overall strategy..

# %% [markdown]
# Gate location:
#
# Let us analyze Gate location

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Gate location"],hue=df1["satisfaction"],palette=("Green","Violet"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# It appears that the gate location and its impact on overall satisfaction is weak. Even a score of 4 for gate location returns a dissatisfaction rate of 61%. Furthermore, for personal travelers the dissatisfaction rate increases by a percentage point between 4 and 5. Even for business travelers, the value of improved gate location appears to be limited.
# Moreover, gate location is not an aspect which the airline could improve so that it will benefit all customers. Given the design of the airport, some gate locations will be inconvenient compared to other. It is rather for the airport to ensure that passengers can arrive at the said gate without delay and confusion.

# %% [markdown]
# Seat comfort:

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Seat comfort"],hue=df1["satisfaction"],palette=("Green","DarkBlue"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Seat comfort, like may of the other variables, show that an increase in scores lead to a decrease in overall dissatisfaction. This is shared with both parties, business and personal travelers. However, the margins greatly differ. For business travelers there is a 55 percentage point difference in the level of overall dissatisfaction whilst for personal travelers, it is less than a percentage point.
# Examining the data with respect to class indicates that business class travelers were extremely likely to view the overall experience in a favorable light if they found the seats comfortable. The dissatisfaction amongst those who rated the seat comfort as 5 were only 8%. However the scale of fluctuations amongst Eco and Eco-Plus is limited.
# This is not unusual as for reduced ticket prices airlines aim to cut costs in other ways. That said, the airline should monitor the situation to ensure that discomfort does not lead to poor online reviews and affect the airline's bottom light.

# %% [markdown]
# Leg room service:

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Leg room service"],hue=df1["satisfaction"],palette=("lightGreen","Blue"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Leg room is a common topic of consideration for travelers and the passengers for this airline is no exception. Overall, as well as breakdown by traveler type all indicate that as the scores on leg room services increase, the satisfaction level also increased.
# The level of changes amongst personal travelers, however, is somewhat limited compared to business travelers. reviewing the travel class indicates that the issue lies with the Economy tickets. As such, this could be a reflection of intentional actions by the airline to keep such ticket prices low. (Reduced leg space for more seating at a reduced price.)

# %% [markdown]
# Cleanliness:

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Cleanliness"],hue=df1["satisfaction"],palette=("Black","Orange"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# On an upper level view, cleanliness appears to be valued by passengers. Furthermore, if the airline wishes to secure more business travellers, investment here may be valued as there is an approx. 56.5 percentage point difference in those who scored cleanliness as 1 and 5 and their level of overall satisfaction.
# For those travelling for personal reasons were less affected by cleanliness. However, unlike other aspects, class does not appear to have an impact on how cleanliness appear to be the critical factor. As such, whilst cleanliness is important, it is not a major factor defining satisfaction. This is to say, additional investment into cleanliness at this time is not required. Cost cutting and other decreases in quality of service should, however, be done with caution.

# %% [markdown]
# In flight WIFI service:

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Inflight wifi service"],hue=df1["satisfaction"],palette=("Pink","Red"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# WIFI appears to follow the trend expected based on the overall result of the services. As the experience improves the passenger's rating of the overall service also altered. The dissatisfaction rate dropped approx. 35%
# Therefore, it could be said that improvements here may lead to major gains for the airline. That said, as 3 is the median rating a passenger could provide, increasing satisfaction from 3 to 4 may prove to be challenging.
# Examining the data under the lens of travel type, highlights further information. For business travelers, between the score of 2 and 3, there is a drop in dissatisfaction by just under 1%. As such, investing in WIFI may likely to further improve the overall satisfaction rating. As for personal travel, for those who rated the service between 1 and 3, reported that they were dissatisfied with the service overall. This drastic difference between business and personal travelers suggest there may be a factor underpinning their experience of in flight WIFI. This underling factor appears the travel class. Similar levels of dissatisfaction can be noted as per the below tables.
# Inferring from this, it is likely that there may be caveats to using the in flight WIFI for Eco and Eco-plus passengers which affect their view of the service and in turn the overall rating of the service. For instance additional costs which are too high. The Airline may wish to investigate the issues pertaining to this services with particular focus on Eco and Eco Plus class.

# %% [markdown]
# Food & drink:
#
# Let us analyze column Food and Drink

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Food and drink"],hue=df1["satisfaction"],palette=("Pink","lightGreen"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Food appears to have a similar impact on overall satisfaction as WIFI. Increases in the food score appears to show a decline in the overall dissatisfaction. However, the scale of shift appears to be limited in comparison to WIFI.
# As before, the variable can be reviewed in context with the purpose of the travel. This indicates that business travellers were more appreciative of the quality of food than personal travellers. In addition. based upon the rate of dissatisfaction of personal travellers, the airline may benefit from first focusing on WIFI and then on food if these two variables were their primary focus.

# %% [markdown]
# In flight entertainment:
#
# Let us find the ratings of In flight entertainment.

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Inflight entertainment"],hue=df1["satisfaction"],palette=("Yellow","Blue"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In flight entertainment show that those who rated the entertainment highly, also found the overall service satisfactory. Business travelers were particularly sensitive to good entertainment with a 67 percentage point decrease in dissatisfaction as scores on entertainment increase.
# In contrast, for personal travelers the dissatisfaction is relatively stable at around 89-90%. Reviewing the travel class highlights that the issue may lie with the offerings made to Eco travelers. The differences between Eco and Eco-Plus suggest either that the offering itself differs or that the passengers expected better and the airline is failing to match this expectation. In either case, the airline may need to re-evaluate it's entertainment offering for Eco and in turn Eco-Plus passengers. (Evaluating only Eco passengers may lead to issues as the difference between Eco and Eco-Plus may become too narrow to justify the difference in ticket prices)

# %% [markdown]
# Onboard service:

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["On-board service"],hue=df1["satisfaction"],palette=("Black","Red"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Onboard services follow a similar trend to other services which relate to in flight conditions, those who rated the services highly were also more likely to view the overall service as satisfactory. Once again, business travelers were more sensitive to the quality of onboard services than personal travelers. As such, if the airline has a focus on business travelers, they may justify the increased investment in this remit.

# %% [markdown]
# In flight service:
#
# Let us analyze this column

# %%
plt.figure(figsize=(12,9))
sns.countplot(df1["Inflight service"],hue=df1["satisfaction"],palette=("Pink","orange"))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In flight services follow a familiar pattern of increased scores appearing to correlate with higher overall satisfaction. However, the pivotal point is relatively high as the balance in favor of satisfied only dominates amongst those who rated the in flight services as a 5. This suggest that this is not a major factor affecting the passenger's view of the airline. Therefore, the airline may see greater benefits in investing in other areas before turning their attention to in flight services..

# %% [markdown]
# ## Statistical Conclusion:
#
# •	Let us see the statistical values of all columns. We will check columns distribution, statistical values and how they are correlated.
#
# First let us check with categorical values.

# %%
df1.describe(include = ['object'])
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count   103904          103904           103904    103904
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     52727           84923            71655     49665
#
#                    satisfaction
# count                    103904
# unique                        2
# top     neutral or dissatisfied
# freq                      58879

# %% [markdown]
# So here we can see there are five categorical variables in dataset. Actually there is nothing to see statistical values in categorical variables but I have just taken this to show count, unique, top and its frequency of categorical variables. So we can see the columns Gender, customer Type, Type of Travel, class, Satisfaction has the count of 103904 values and in all columns expect class there 2 unique values whereas in class there are 3 unique values. we can see top and its frequency.
#
# Now let us come to numerical values which are more important for statistical conclusion.

# %%
df1.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean       39.379706      1189.448375               2.729683
# std        15.114964       997.147281               1.327829
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       843.000000               3.000000
# 75%        51.000000      1743.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %% [markdown]
# Let us take only numerical columns which are import for the stats.
#
# First let us analyze the age column. In Age column the count of values is 103904 its max value is 85 and min value is 7. The average age is 39.The standard deviation age is 15. The 50th percentile of age is 40. Let us see distribution Age.

# %%
sns.distplot(df.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Now let us check the Flight Distance. The Flight Distance also have the count of values 103904. Surprisingly the minimum Flight Distance is 31 and maximum Flight Distance is 4983. The average Flight Distance is 1189 and 50th percentile of this column is 843.The Standard Deviation is 997.14. Let us check the distribution of Flight Distance.

# %%
sns.distplot(df["Flight Distance"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see the plot that the values are normally distributed so the values are in continuous. So the Flight Distance is Continuous numerical data type.
#
# Let us check with Ratings. As we can see all the values are ratings it has min of 0 and max of 5.These values shows the binomial Distribution so these values are Discrete numerical Data type.
#
# Let us check with Delays. The Departure Delay has the min value of 0 so we can say there are some flights which are departure without delay and max value is surprisingly 1592 minutes. The standard deviation of Departure Delay is 38.23 and average departure delay is 14.81.Let us check the distribution of Departure Delay.

# %%
sns.distplot(df1["Departure Delay in Minutes"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see analyze from the plot is all values are in continuous since it is in Normal distribution. We can see it is a left Skewed Normal Distribution.
#
# Let us check Arrival delay. The min value of arrival delay is 0 so we can analyze that there are some flight which has no delay in arrival and the max value is 1584 minutes. The average arrival Delay is 15.17 minutes and its standard deviation is 38.Let us see the distribution of arrival Delay

# %%
sns.distplot(df1["Arrival Delay in Minutes"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# So we can see it is similar to departure delay these values are also continuous since it is Normally distributed. So we have to see any relation between  Departure delay and arrival delay.
#
# Let us see the correlation of values in this data set.

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df1.corr(),annot=True,cmap="Blues")

# %% [markdown]
# So as we thought highest correlated values are departure delay and arrival delay. We can say logically also if departure is delay automatically arrival will be also delayed .The correlation of both these columns are 0.97.

# %% [markdown]
# ##Multivariate Analysis
#
#
# *  Multivariate analysis:- is performed to understand interactions between different fields in the dataset (or) finding interactions between variables more than 2. Ex:- Pair plot

# %%
sns.pairplot(df1,hue="satisfaction",vars=["Arrival Delay in Minutes","Departure Delay in Minutes","Flight Distance"])

# %%
plt.figure(figsize = (20,10))
sns.violinplot(x = 'Departure Delay in Minutes', data = df1,y= "Class", hue ="satisfaction",  palette ="Paired")
plt.suptitle("Satisfaction results by Departure Delay in minutes")
sns.despine(top = True, right = True, left = False, bottom = False)

plt.show()

# %%
plt.figure(figsize = (20,10))

sns.violinplot(x = "Arrival Delay in Minutes", data = df, y= "Class", hue ="satisfaction", height = 8,palette ="Paired"  )
plt.title("Satisfaction results by Arrival Delay in minutes")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %%
plt.figure(figsize = (20,10))

sns.displot(x = "Arrival Delay in Minutes", data = df1, y= "Type of Travel", hue ="satisfaction", height = 8,palette =["Red","Yellow"])
plt.title("Satisfaction results by Arrival Delay in minutes")
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %% [markdown]
# ###CONCLUSION
# This is a report evaluating an airline passenger satisfaction survey. It shows some concerning insights pertaining to low levels of satisfaction of the services. Without discussions with the airline, it is unclear whether aspects of this dissatisfaction is related to the airline's intentional strategy, focusing on business travelers. If not, the airline has noticeable weaknesses in its offering to personal travelers and especially those travelling via economy or economy plus flights. Therefore if not intention, the airline may need to invest into improving this aspect of their business.
# If the airline does specialize in business travelers, it may still be in need of modernization as younger business travelers voiced dissatisfaction with the services.
# Although there are a plethora of aspects that the airline needs to invest, tackling aspects such as their online offering may yield the best results for both business and personal travelers. Moreover as younger users are most likely to use such services, this should also be positively received by the younger demography.

# %% [markdown]
# ###SUGGESTIONS
#
# So as we analyze the different columns in the dataset we have came to the conclusions so these are some the suggestions to improve the satisfaction of passengers of airline.
# •	In Type Of Travel mostly personal travelers are dissatisfied this may be the issue of delays or service. So they have to increase service which satisfies the personal travelers and also business travelers.
# •	In classes Mostly Economic classes are  dissatisfied. Whilst this suggest a need for the airline to investigate its Economy ticket offering, there is a need to confirm with the airline on their strategic decisions. If the airline wishes to be one which predominantly cater for business travelers, this aspect may have been accounted for and accepted. Given that there are more business class travelers, the airline may be justified in their decision but it will be dependent on the profitability of this strategy.
# •	In Age mostly younger generations are dissatisfied so airlines should concentrate service which make younger generation also satisfied that may be online ticket booking, in-flight entertainment etc.
# •	In Flight Distances as the Flight Distance increasing the satisfaction rate is increasing. So airline should concentrate on the services in shorter distances flights. There can be also one reason that customers cannot judge the services on shortest distance flights because if distance is shorter the travelling time will be shorter so they cannot judge the services but also airlines should look into this.
# •	In Delays has delays increasing satisfaction also decreasing so airline should concentrate the delays and decrease the delays.
# •	In services there are some services which should concreted by the airlines which are mentioned in analysis of services.
